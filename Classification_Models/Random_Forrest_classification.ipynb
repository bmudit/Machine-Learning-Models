# %% [markdown]
# ## Importing the basic libraries for data manupulation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing the data

# %%
dataset = pd.read_csv('File_directory')
X = dataset.iloc[:,:-1].values # assuming the target column is the last one
y = dataset.iloc[:,-1].values

# %% [markdown]
# ## Taking care of missing data

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan,strategy='mean')
imputer.fit(X) #X represents the required dataset
X = imputer.transform(X) #X represents the required dataset

# %% [markdown]
# ##Encoding Categorical data

# %% [markdown]
# ###OneHot Encoder

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
tool_1 = ColumnTransformer(transformers = [('encoder', OneHotEncoder(), [column_no.])], remainder = 'passthrough') # enter the column no. which needs to be encoded
X = np.array(tool_1.fit_transform(X))

# %% [markdown]
# ###Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder
tool_2 = LabelEncoder()
X = tool_2.fit_transform(X) # X represents the required dataset

# %% [markdown]
# ##Splitting the data into train and test set

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# ##Feature scaling

# %%
from sklearn.preprocessing import StandardScaler
tool_3_X = StandardScaler()
tool_3_y= StandardScaler()

X_train=tool_3_X.fit_transform(X_train)
X_test = tool_3_X.transform(X_test)

y_train=tool_3_y.fit_transform(y_train) #remember to inverse the scaling while making prediction

# %% [markdown]
# ##Training Decision Tree Model

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
classifier.fit(X_train, y_train)

# %% [markdown]
# ##Making Prediciton

# %%
y_prediction = classifier.predict(X_test)

# %% [markdown]
# ##Making confusion matrix and calculating model performance

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
matrix = confusion_matrix(y_test, y_prediction)
accuracy = accuracy_score(y_test, y_prediction)
